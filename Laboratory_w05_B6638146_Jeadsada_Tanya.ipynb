# %% [markdown]
# #**Random Forest Project**

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Get the Data**

# %%
df = pd.read_csv('/content/drive/MyDrive/SCI19 3621 Machine Learning/loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
plt.figure(figsize=(10,6))
df[df['credit.policy'] == 1]['fico'].hist(alpha=0.5, color='b', bins=30, label='Credit.Policy=1')
df[df['credit.policy'] == 0]['fico'].hist(alpha=0.5, color='r', bins=30, label='Credit.Policy=0')
plt.xlabel('FICO')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='fico',hue='not.fully.paid',bins=30,palette={1: 'blue', 0: 'red'},alpha=0.6)
plt.legend(labels=['not fully paid=1', 'not fully paid=0'])
plt.xlabel('FICO')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df,x='purpose',hue='not.fully.paid',palette={1: 'blue', 0: 'red'}  )

plt.xlabel('Purpose')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='not.fully.paid', labels=['not fully paid=0', 'not fully paid=1'])
plt.show()

# %%
sns.jointplot(data=df,x='fico',y='int.rate',kind='scatter',color='purple',alpha=0.6)
plt.show()

# %%
sns.lmplot(data=df,x='fico',y='int.rate',hue='credit.policy',col='not.fully.paid',palette={1: 'blue', 0: 'red'},height=6,aspect=1)
plt.show()

# %% [markdown]
# # **Setting up the Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# # **Categorical Features**

# %%
cat_feats = ['purpose']
final_data = pd.get_dummies(df, columns=cat_feats, drop_first=True)

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # **Training a Decision Tree Model**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtre = DecisionTreeClassifier()
dtre.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # **Predictions and Evaluation of Decision Tree**

# %%
from sklearn.metrics import classification_report, confusion_matrix
predictions = dtre.predict(X_test)
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83      2431
#            1       0.19      0.24      0.21       443
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.53      0.52      2874
# weighted avg       0.75      0.73      0.74      2874
#
# [[1984  447]
#  [ 338  105]]

# %% [markdown]
# # **Training the Random Forest model**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # **Predictions and Evaluation**

# %%
rfc_predictions = rfc.predict(X_test)

# %%
print(classification_report(y_test, rfc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.52      0.02      0.05       443
#
#     accuracy                           0.85      2874
#    macro avg       0.69      0.51      0.48      2874
# weighted avg       0.80      0.85      0.78      2874

# %%
print(confusion_matrix(y_test, rfc_predictions))
# Out:
# [[2421   10]
#  [ 432   11]]

# %% [markdown]
# **What performed better the random forest or the decision tree?**

# %% [markdown]
# Random Forest ให้ผลลัพธ์ที่ดีกว่า Decision Tree
# เนื่องจากเป็นเทคนิคที่รวมต้นไม้หลายๆ ต้นเข้าด้วยกัน ทำให้ลดโอกาสการเกิด overfitting และมีความแม่นยำสูงกว่า
